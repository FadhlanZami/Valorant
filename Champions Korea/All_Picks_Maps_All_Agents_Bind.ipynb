# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, classification_report 
import seaborn as sns

# %%
data=pd.read_excel(r"C:\Users\Ubaidil\Downloads\vct_2024\agents\agent_pick_rates.xlsx")
Data_champions = data[data['Tournament'].isin(['Valorant Champions 2024'])]

# %%
Data_allStages = Data_champions[Data_champions['Stage'].isin(['All Stages'])]
Data_allStages
# Out:
#                    Tournament       Stage       Match Type       Map    Agent  \
# 2448  Valorant Champions 2024  All Stages  All Match Types  All Maps     omen
# 2449  Valorant Champions 2024  All Stages  All Match Types  All Maps     sova
# 2450  Valorant Champions 2024  All Stages  All Match Types  All Maps    viper
# 2451  Valorant Champions 2024  All Stages  All Match Types  All Maps   cypher
# 2452  Valorant Champions 2024  All Stages  All Match Types  All Maps     raze
# ...                       ...         ...              ...       ...      ...
# 2635  Valorant Champions 2024  All Stages  All Match Types    Ascent    clove
# 2636  Valorant Champions 2024  All Stages  All Match Types    Ascent  chamber
# 2637  Valorant Champions 2024  All Stages  All Match Types    Ascent      iso
# 2638  Valorant Champions 2024  All Stages  All Match Types    Ascent  phoenix
# 2639  Valorant Champions 2024  All Stages  All Match Types    Ascent    reyna
#
#       Pick Rate
# 2448       0.62
# 2449       0.52
# 2450       0.50
# 2451       0.42
# 2452       0.41
# ...         ...
# 2635       0.13
# 2636       0.00
# 2637       0.00
# 2638       0.13
# 2639       0.00
#
# [192 rows x 6 columns]

# %%
Data_AllMaps = Data_allStages[Data_allStages['Map'].isin(['Bind'])]
Data_AllMaps
# Out:
#                    Tournament       Stage       Match Type   Map      Agent  \
# 2496  Valorant Champions 2024  All Stages  All Match Types  Bind       omen
# 2497  Valorant Champions 2024  All Stages  All Match Types  Bind       sova
# 2498  Valorant Champions 2024  All Stages  All Match Types  Bind      viper
# 2499  Valorant Champions 2024  All Stages  All Match Types  Bind     cypher
# 2500  Valorant Champions 2024  All Stages  All Match Types  Bind       raze
# 2501  Valorant Champions 2024  All Stages  All Match Types  Bind       fade
# 2502  Valorant Champions 2024  All Stages  All Match Types  Bind    killjoy
# 2503  Valorant Champions 2024  All Stages  All Match Types  Bind       jett
# 2504  Valorant Champions 2024  All Stages  All Match Types  Bind      gekko
# 2505  Valorant Champions 2024  All Stages  All Match Types  Bind     breach
# 2506  Valorant Champions 2024  All Stages  All Match Types  Bind       neon
# 2507  Valorant Champions 2024  All Stages  All Match Types  Bind       kayo
# 2508  Valorant Champions 2024  All Stages  All Match Types  Bind  brimstone
# 2509  Valorant Champions 2024  All Stages  All Match Types  Bind      astra
# 2510  Valorant Champions 2024  All Stages  All Match Types  Bind       skye
# 2511  Valorant Champions 2024  All Stages  All Match Types  Bind       yoru
# 2512  Valorant Champions 2024  All Stages  All Match Types  Bind     harbor
# 2513  Valorant Champions 2024  All Stages  All Match Types  Bind   deadlock
# 2514  Valorant Champions 2024  All Stages  All Match Types  Bind       sage
# 2515  Valorant Champions 2024  All Stages  All Match Types  Bind      clove
# 2516  Valorant Champions 2024  All Stages  All Match Types  Bind    chamber
# 2517  Valorant Champions 2024  All Stages  All Match Types  Bind        iso
# 2518  Valorant Champions 2024  All Stages  All Match Types  Bind    phoenix
# 2519  Valorant Champions 2024  All Stages  All Match Types  Bind      reyna
#
#       Pick Rate
# 2496       0.13
# 2497       0.00
# 2498       0.90
# 2499       0.17
# 2500       0.87
# 2501       0.63
# 2502       0.00
# 2503       0.00
# 2504       0.73
# 2505       0.00
# 2506       0.03
# 2507       0.00
# 2508       0.73
# 2509       0.13
# 2510       0.37
# 2511       0.13
# 2512       0.00
# 2513       0.10
# 2514       0.00
# 2515       0.00
# 2516       0.07
# 2517       0.00
# 2518       0.00
# 2519       0.00

# %%
Agentspick = Data_AllMaps[['Agent','Pick Rate']]
Agentspick

# Membuat DataFrame
AgentspickLotus = pd.DataFrame(Agentspick)

# Menghapus baris dengan 'Pick Rate' yang bernilai 0
AgentspickLotus_cleaned = AgentspickLotus[AgentspickLotus['Pick Rate'] != 0]

# %%
AgentspickLotus_cleaned
# Out:
#           Agent  Pick Rate
# 2496       omen       0.13
# 2498      viper       0.90
# 2499     cypher       0.17
# 2500       raze       0.87
# 2501       fade       0.63
# 2504      gekko       0.73
# 2506       neon       0.03
# 2508  brimstone       0.73
# 2509      astra       0.13
# 2510       skye       0.37
# 2511       yoru       0.13
# 2513   deadlock       0.10
# 2516    chamber       0.07

# %%
AgentspickLotus_cleaned['Pick Rate'] = AgentspickLotus_cleaned['Pick Rate'] * 100
AgentspickLotus_cleaned = AgentspickLotus_cleaned.sort_values(by='Pick Rate', ascending=False)
plt.bar(AgentspickLotus_cleaned['Agent'], AgentspickLotus_cleaned['Pick Rate'], color='skyblue')
plt.title('Pick Rate of Agents Chammpions Korea (Map Bind)')
plt.xlabel('Agent ')
plt.ylabel('Pick Rate (%)')
plt.xticks(rotation=45, ha='right')

# Menampilkan plot
plt.tight_layout()  # Agar layout lebih rapih
plt.show()
# Out:
# C:\Users\Ubaidil\AppData\Local\Temp\ipykernel_896\909821252.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   AgentspickLotus_cleaned['Pick Rate'] = AgentspickLotus_cleaned['Pick Rate'] * 100

# %%
file_path = 'AgentsPickChampionsKoreabind.xlsx'                            
Agentspick.to_excel(file_path, index=False, engine='openpyxl')

print(f"Data berhasil disimpan ke {file_path}")
# Out:
# Data berhasil disimpan ke AgentsPickChampionsKoreabind.xlsx
