# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, classification_report 
import seaborn as sns

# %%
data=pd.read_excel(r"C:\Users\Ubaidil\Downloads\vct_2024\agents\agent_pick_rates.xlsx")
Data_champions = data[data['Tournament'].isin(['Valorant Champions 2024'])]

# %%
Data_allStages = Data_champions[Data_champions['Stage'].isin(['All Stages'])]
Data_allStages
# Out:
#                    Tournament       Stage       Match Type       Map    Agent  \
# 2448  Valorant Champions 2024  All Stages  All Match Types  All Maps     omen
# 2449  Valorant Champions 2024  All Stages  All Match Types  All Maps     sova
# 2450  Valorant Champions 2024  All Stages  All Match Types  All Maps    viper
# 2451  Valorant Champions 2024  All Stages  All Match Types  All Maps   cypher
# 2452  Valorant Champions 2024  All Stages  All Match Types  All Maps     raze
# ...                       ...         ...              ...       ...      ...
# 2635  Valorant Champions 2024  All Stages  All Match Types    Ascent    clove
# 2636  Valorant Champions 2024  All Stages  All Match Types    Ascent  chamber
# 2637  Valorant Champions 2024  All Stages  All Match Types    Ascent      iso
# 2638  Valorant Champions 2024  All Stages  All Match Types    Ascent  phoenix
# 2639  Valorant Champions 2024  All Stages  All Match Types    Ascent    reyna
#
#       Pick Rate
# 2448       0.62
# 2449       0.52
# 2450       0.50
# 2451       0.42
# 2452       0.41
# ...         ...
# 2635       0.13
# 2636       0.00
# 2637       0.00
# 2638       0.13
# 2639       0.00
#
# [192 rows x 6 columns]

# %%
Data_AllMaps = Data_allStages[Data_allStages['Map'].isin(['Icebox'])]
Data_AllMaps
# Out:
#                    Tournament       Stage       Match Type     Map      Agent  \
# 2568  Valorant Champions 2024  All Stages  All Match Types  Icebox       omen
# 2569  Valorant Champions 2024  All Stages  All Match Types  Icebox       sova
# 2570  Valorant Champions 2024  All Stages  All Match Types  Icebox      viper
# 2571  Valorant Champions 2024  All Stages  All Match Types  Icebox     cypher
# 2572  Valorant Champions 2024  All Stages  All Match Types  Icebox       raze
# 2573  Valorant Champions 2024  All Stages  All Match Types  Icebox       fade
# 2574  Valorant Champions 2024  All Stages  All Match Types  Icebox    killjoy
# 2575  Valorant Champions 2024  All Stages  All Match Types  Icebox       jett
# 2576  Valorant Champions 2024  All Stages  All Match Types  Icebox      gekko
# 2577  Valorant Champions 2024  All Stages  All Match Types  Icebox     breach
# 2578  Valorant Champions 2024  All Stages  All Match Types  Icebox       neon
# 2579  Valorant Champions 2024  All Stages  All Match Types  Icebox       kayo
# 2580  Valorant Champions 2024  All Stages  All Match Types  Icebox  brimstone
# 2581  Valorant Champions 2024  All Stages  All Match Types  Icebox      astra
# 2582  Valorant Champions 2024  All Stages  All Match Types  Icebox       skye
# 2583  Valorant Champions 2024  All Stages  All Match Types  Icebox       yoru
# 2584  Valorant Champions 2024  All Stages  All Match Types  Icebox     harbor
# 2585  Valorant Champions 2024  All Stages  All Match Types  Icebox   deadlock
# 2586  Valorant Champions 2024  All Stages  All Match Types  Icebox       sage
# 2587  Valorant Champions 2024  All Stages  All Match Types  Icebox      clove
# 2588  Valorant Champions 2024  All Stages  All Match Types  Icebox    chamber
# 2589  Valorant Champions 2024  All Stages  All Match Types  Icebox        iso
# 2590  Valorant Champions 2024  All Stages  All Match Types  Icebox    phoenix
# 2591  Valorant Champions 2024  All Stages  All Match Types  Icebox      reyna
#
#       Pick Rate
# 2568       0.00
# 2569       0.92
# 2570       1.00
# 2571       0.00
# 2572       0.00
# 2573       0.00
# 2574       1.00
# 2575       0.71
# 2576       0.42
# 2577       0.00
# 2578       0.17
# 2579       0.33
# 2580       0.00
# 2581       0.00
# 2582       0.00
# 2583       0.00
# 2584       0.33
# 2585       0.00
# 2586       0.13
# 2587       0.00
# 2588       0.00
# 2589       0.00
# 2590       0.00
# 2591       0.00

# %%
Agentspick = Data_AllMaps[['Agent','Pick Rate']]
Agentspick

# Membuat DataFrame
AgentspickLotus = pd.DataFrame(Agentspick)

# Menghapus baris dengan 'Pick Rate' yang bernilai 0
AgentspickLotus_cleaned = AgentspickLotus[AgentspickLotus['Pick Rate'] != 0]

# %%
AgentspickLotus_cleaned
# Out:
#         Agent  Pick Rate
# 2569     sova       0.92
# 2570    viper       1.00
# 2574  killjoy       1.00
# 2575     jett       0.71
# 2576    gekko       0.42
# 2578     neon       0.17
# 2579     kayo       0.33
# 2584   harbor       0.33
# 2586     sage       0.13

# %%
AgentspickLotus_cleaned['Pick Rate'] = AgentspickLotus_cleaned['Pick Rate'] * 100
AgentspickLotus_cleaned = AgentspickLotus_cleaned.sort_values(by='Pick Rate', ascending=False)
plt.bar(AgentspickLotus_cleaned['Agent'], AgentspickLotus_cleaned['Pick Rate'], color='skyblue')
plt.title('Pick Rate of Agents Chammpions Korea (Map Icebox)')
plt.xlabel('Agent ')
plt.ylabel('Pick Rate (%)')
plt.xticks(rotation=45, ha='right')

# Menampilkan plot
plt.tight_layout()  # Agar layout lebih rapih
plt.show()
# Out:
# C:\Users\Ubaidil\AppData\Local\Temp\ipykernel_824\3423490405.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   AgentspickLotus_cleaned['Pick Rate'] = AgentspickLotus_cleaned['Pick Rate'] * 100

# %%
file_path = 'AgentsPickChampionsKoreaIcebox.xlsx'                       
Agentspick.to_excel(file_path, index=False, engine='openpyxl')

print(f"Data berhasil disimpan ke {file_path}")
# Out:
# Data berhasil disimpan ke AgentsPickChampionsKoreaIcebox.xlsx
