# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, classification_report 
import seaborn as sns

# %%
data=pd.read_excel(r"C:\Users\Ubaidil\Downloads\vct_2024\agents\agent_pick_rates.xlsx")
Data_champions = data[data['Tournament'].isin(['Valorant Champions 2024'])]

# %%
Data_allStages = Data_champions[Data_champions['Stage'].isin(['All Stages'])]
Data_allStages
# Out:
#                    Tournament       Stage       Match Type       Map    Agent  \
# 2448  Valorant Champions 2024  All Stages  All Match Types  All Maps     omen
# 2449  Valorant Champions 2024  All Stages  All Match Types  All Maps     sova
# 2450  Valorant Champions 2024  All Stages  All Match Types  All Maps    viper
# 2451  Valorant Champions 2024  All Stages  All Match Types  All Maps   cypher
# 2452  Valorant Champions 2024  All Stages  All Match Types  All Maps     raze
# ...                       ...         ...              ...       ...      ...
# 2635  Valorant Champions 2024  All Stages  All Match Types    Ascent    clove
# 2636  Valorant Champions 2024  All Stages  All Match Types    Ascent  chamber
# 2637  Valorant Champions 2024  All Stages  All Match Types    Ascent      iso
# 2638  Valorant Champions 2024  All Stages  All Match Types    Ascent  phoenix
# 2639  Valorant Champions 2024  All Stages  All Match Types    Ascent    reyna
#
#       Pick Rate
# 2448       0.62
# 2449       0.52
# 2450       0.50
# 2451       0.42
# 2452       0.41
# ...         ...
# 2635       0.13
# 2636       0.00
# 2637       0.00
# 2638       0.13
# 2639       0.00
#
# [192 rows x 6 columns]

# %%
Data_AllMaps = Data_allStages[Data_allStages['Map'].isin(['Lotus'])]
Data_AllMaps
# Out:
#                    Tournament       Stage       Match Type    Map      Agent  \
# 2472  Valorant Champions 2024  All Stages  All Match Types  Lotus       omen
# 2473  Valorant Champions 2024  All Stages  All Match Types  Lotus       sova
# 2474  Valorant Champions 2024  All Stages  All Match Types  Lotus      viper
# 2475  Valorant Champions 2024  All Stages  All Match Types  Lotus     cypher
# 2476  Valorant Champions 2024  All Stages  All Match Types  Lotus       raze
# 2477  Valorant Champions 2024  All Stages  All Match Types  Lotus       fade
# 2478  Valorant Champions 2024  All Stages  All Match Types  Lotus    killjoy
# 2479  Valorant Champions 2024  All Stages  All Match Types  Lotus       jett
# 2480  Valorant Champions 2024  All Stages  All Match Types  Lotus      gekko
# 2481  Valorant Champions 2024  All Stages  All Match Types  Lotus     breach
# 2482  Valorant Champions 2024  All Stages  All Match Types  Lotus       neon
# 2483  Valorant Champions 2024  All Stages  All Match Types  Lotus       kayo
# 2484  Valorant Champions 2024  All Stages  All Match Types  Lotus  brimstone
# 2485  Valorant Champions 2024  All Stages  All Match Types  Lotus      astra
# 2486  Valorant Champions 2024  All Stages  All Match Types  Lotus       skye
# 2487  Valorant Champions 2024  All Stages  All Match Types  Lotus       yoru
# 2488  Valorant Champions 2024  All Stages  All Match Types  Lotus     harbor
# 2489  Valorant Champions 2024  All Stages  All Match Types  Lotus   deadlock
# 2490  Valorant Champions 2024  All Stages  All Match Types  Lotus       sage
# 2491  Valorant Champions 2024  All Stages  All Match Types  Lotus      clove
# 2492  Valorant Champions 2024  All Stages  All Match Types  Lotus    chamber
# 2493  Valorant Champions 2024  All Stages  All Match Types  Lotus        iso
# 2494  Valorant Champions 2024  All Stages  All Match Types  Lotus    phoenix
# 2495  Valorant Champions 2024  All Stages  All Match Types  Lotus      reyna
#
#       Pick Rate
# 2472       1.00
# 2473       0.00
# 2474       0.68
# 2475       0.18
# 2476       0.75
# 2477       0.90
# 2478       0.53
# 2479       0.08
# 2480       0.05
# 2481       0.33
# 2482       0.20
# 2483       0.03
# 2484       0.00
# 2485       0.03
# 2486       0.03
# 2487       0.00
# 2488       0.00
# 2489       0.03
# 2490       0.00
# 2491       0.15
# 2492       0.08
# 2493       0.00
# 2494       0.00
# 2495       0.00

# %%
Agentspick = Data_AllMaps[['Agent','Pick Rate']]
Agentspick

# Membuat DataFrame
AgentspickLotus = pd.DataFrame(Agentspick)

# Menghapus baris dengan 'Pick Rate' yang bernilai 0
AgentspickLotus_cleaned = AgentspickLotus[AgentspickLotus['Pick Rate'] != 0]

# %%
AgentspickLotus_cleaned
# Out:
#          Agent  Pick Rate
# 2472      omen       1.00
# 2474     viper       0.68
# 2475    cypher       0.18
# 2476      raze       0.75
# 2477      fade       0.90
# 2478   killjoy       0.53
# 2479      jett       0.08
# 2480     gekko       0.05
# 2481    breach       0.33
# 2482      neon       0.20
# 2483      kayo       0.03
# 2485     astra       0.03
# 2486      skye       0.03
# 2489  deadlock       0.03
# 2491     clove       0.15
# 2492   chamber       0.08

# %%
AgentspickLotus_cleaned['Pick Rate'] = AgentspickLotus_cleaned['Pick Rate'] * 100
AgentspickLotus_cleaned = AgentspickLotus_cleaned.sort_values(by='Pick Rate', ascending=False)
plt.bar(AgentspickLotus_cleaned['Agent'], AgentspickLotus_cleaned['Pick Rate'], color='skyblue')
plt.title('Pick Rate of Agents Chammpions Korea (Map Lotus) ')
plt.xlabel('Agent ')
plt.ylabel('Pick Rate (%)')
plt.xticks(rotation=45, ha='right')

# Menampilkan plot
plt.tight_layout()  # Agar layout lebih rapih
plt.show()

# %%
file_path = 'AgentsPickChampionsKoreaLotus.xlsx'  # Nama file yang ingin disimpan
Agentspick.to_excel(file_path, index=False, engine='openpyxl')

print(f"Data berhasil disimpan ke {file_path}")
# Out:
# Data berhasil disimpan ke AgentsPickChampionsKoreaLotus.xlsx
