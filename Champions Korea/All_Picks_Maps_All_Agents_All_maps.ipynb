# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, classification_report 
import seaborn as sns

# %%
data=pd.read_excel(r"C:\Users\Ubaidil\Downloads\vct_2024\agents\agent_pick_rates.xlsx")
Data_champions = data[data['Tournament'].isin(['Valorant Champions 2024'])]

# %%
Data_allStages = Data_champions[Data_champions['Stage'].isin(['All Stages'])]
Data_allStages
# Out:
#                    Tournament       Stage       Match Type       Map    Agent  \
# 2448  Valorant Champions 2024  All Stages  All Match Types  All Maps     omen
# 2449  Valorant Champions 2024  All Stages  All Match Types  All Maps     sova
# 2450  Valorant Champions 2024  All Stages  All Match Types  All Maps    viper
# 2451  Valorant Champions 2024  All Stages  All Match Types  All Maps   cypher
# 2452  Valorant Champions 2024  All Stages  All Match Types  All Maps     raze
# ...                       ...         ...              ...       ...      ...
# 2635  Valorant Champions 2024  All Stages  All Match Types    Ascent    clove
# 2636  Valorant Champions 2024  All Stages  All Match Types    Ascent  chamber
# 2637  Valorant Champions 2024  All Stages  All Match Types    Ascent      iso
# 2638  Valorant Champions 2024  All Stages  All Match Types    Ascent  phoenix
# 2639  Valorant Champions 2024  All Stages  All Match Types    Ascent    reyna
#
#       Pick Rate
# 2448       0.62
# 2449       0.52
# 2450       0.50
# 2451       0.42
# 2452       0.41
# ...         ...
# 2635       0.13
# 2636       0.00
# 2637       0.00
# 2638       0.13
# 2639       0.00
#
# [192 rows x 6 columns]

# %%
Data_AllMaps = Data_allStages[Data_allStages['Map'].isin(['All Maps'])]
Data_AllMaps
# Out:
#                    Tournament       Stage       Match Type       Map  \
# 2448  Valorant Champions 2024  All Stages  All Match Types  All Maps
# 2449  Valorant Champions 2024  All Stages  All Match Types  All Maps
# 2450  Valorant Champions 2024  All Stages  All Match Types  All Maps
# 2451  Valorant Champions 2024  All Stages  All Match Types  All Maps
# 2452  Valorant Champions 2024  All Stages  All Match Types  All Maps
# 2453  Valorant Champions 2024  All Stages  All Match Types  All Maps
# 2454  Valorant Champions 2024  All Stages  All Match Types  All Maps
# 2455  Valorant Champions 2024  All Stages  All Match Types  All Maps
# 2456  Valorant Champions 2024  All Stages  All Match Types  All Maps
# 2457  Valorant Champions 2024  All Stages  All Match Types  All Maps
# 2458  Valorant Champions 2024  All Stages  All Match Types  All Maps
# 2459  Valorant Champions 2024  All Stages  All Match Types  All Maps
# 2460  Valorant Champions 2024  All Stages  All Match Types  All Maps
# 2461  Valorant Champions 2024  All Stages  All Match Types  All Maps
# 2462  Valorant Champions 2024  All Stages  All Match Types  All Maps
# 2463  Valorant Champions 2024  All Stages  All Match Types  All Maps
# 2464  Valorant Champions 2024  All Stages  All Match Types  All Maps
# 2465  Valorant Champions 2024  All Stages  All Match Types  All Maps
# 2466  Valorant Champions 2024  All Stages  All Match Types  All Maps
# 2467  Valorant Champions 2024  All Stages  All Match Types  All Maps
# 2468  Valorant Champions 2024  All Stages  All Match Types  All Maps
# 2469  Valorant Champions 2024  All Stages  All Match Types  All Maps
# 2470  Valorant Champions 2024  All Stages  All Match Types  All Maps
# 2471  Valorant Champions 2024  All Stages  All Match Types  All Maps
#
#           Agent  Pick Rate
# 2448       omen       0.62
# 2449       sova       0.52
# 2450      viper       0.50
# 2451     cypher       0.42
# 2452       raze       0.41
# 2453       fade       0.34
# 2454    killjoy       0.33
# 2455       jett       0.29
# 2456      gekko       0.27
# 2457     breach       0.24
# 2458       neon       0.22
# 2459       kayo       0.20
# 2460  brimstone       0.13
# 2461      astra       0.12
# 2462       skye       0.08
# 2463       yoru       0.08
# 2464     harbor       0.07
# 2465   deadlock       0.05
# 2466       sage       0.04
# 2467      clove       0.04
# 2468    chamber       0.03
# 2469        iso       0.01
# 2470    phoenix       0.01
# 2471      reyna       0.00

# %%
Agentspick = Data_AllMaps[['Agent','Pick Rate']]

# %%
file_path = 'AgentsPickChampionsKorea.xlsx'  # Nama file yang ingin disimpan
Agentspick.to_excel(file_path, index=False, engine='openpyxl')

print(f"Data berhasil disimpan ke {file_path}")
# Out:
# Data berhasil disimpan ke AgentsPickChampionsKorea.xlsx

# %%
Agentspick['Pick Rate'] = Agentspick['Pick Rate'] * 100
plt.bar(Agentspick['Agent'], Agentspick['Pick Rate'], color='skyblue')
plt.title('Pick Rate of Agents(%)')
plt.xlabel('Agent')
plt.ylabel('Pick Rate')
plt.xticks(rotation=45, ha='right')

# Menampilkan plot
plt.tight_layout()  # Agar layout lebih rapih
plt.show()
# Out:
# C:\Users\Ubaidil\AppData\Local\Temp\ipykernel_12724\1845965147.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Agentspick['Pick Rate'] = Agentspick['Pick Rate'] * 100
