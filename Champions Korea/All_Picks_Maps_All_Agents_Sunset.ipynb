# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, classification_report 
import seaborn as sns

# %%
data=pd.read_excel(r"C:\Users\Ubaidil\Downloads\vct_2024\agents\agent_pick_rates.xlsx")
Data_champions = data[data['Tournament'].isin(['Valorant Champions 2024'])]

# %%
Data_allStages = Data_champions[Data_champions['Stage'].isin(['All Stages'])]
Data_allStages
# Out:
#                    Tournament       Stage       Match Type       Map    Agent  \
# 2448  Valorant Champions 2024  All Stages  All Match Types  All Maps     omen
# 2449  Valorant Champions 2024  All Stages  All Match Types  All Maps     sova
# 2450  Valorant Champions 2024  All Stages  All Match Types  All Maps    viper
# 2451  Valorant Champions 2024  All Stages  All Match Types  All Maps   cypher
# 2452  Valorant Champions 2024  All Stages  All Match Types  All Maps     raze
# ...                       ...         ...              ...       ...      ...
# 2635  Valorant Champions 2024  All Stages  All Match Types    Ascent    clove
# 2636  Valorant Champions 2024  All Stages  All Match Types    Ascent  chamber
# 2637  Valorant Champions 2024  All Stages  All Match Types    Ascent      iso
# 2638  Valorant Champions 2024  All Stages  All Match Types    Ascent  phoenix
# 2639  Valorant Champions 2024  All Stages  All Match Types    Ascent    reyna
#
#       Pick Rate
# 2448       0.62
# 2449       0.52
# 2450       0.50
# 2451       0.42
# 2452       0.41
# ...         ...
# 2635       0.13
# 2636       0.00
# 2637       0.00
# 2638       0.13
# 2639       0.00
#
# [192 rows x 6 columns]

# %%
Data_AllMaps = Data_allStages[Data_allStages['Map'].isin(['Sunset'])]
Data_AllMaps
# Out:
#                    Tournament       Stage       Match Type     Map      Agent  \
# 2520  Valorant Champions 2024  All Stages  All Match Types  Sunset       omen
# 2521  Valorant Champions 2024  All Stages  All Match Types  Sunset       sova
# 2522  Valorant Champions 2024  All Stages  All Match Types  Sunset      viper
# 2523  Valorant Champions 2024  All Stages  All Match Types  Sunset     cypher
# 2524  Valorant Champions 2024  All Stages  All Match Types  Sunset       raze
# 2525  Valorant Champions 2024  All Stages  All Match Types  Sunset       fade
# 2526  Valorant Champions 2024  All Stages  All Match Types  Sunset    killjoy
# 2527  Valorant Champions 2024  All Stages  All Match Types  Sunset       jett
# 2528  Valorant Champions 2024  All Stages  All Match Types  Sunset      gekko
# 2529  Valorant Champions 2024  All Stages  All Match Types  Sunset     breach
# 2530  Valorant Champions 2024  All Stages  All Match Types  Sunset       neon
# 2531  Valorant Champions 2024  All Stages  All Match Types  Sunset       kayo
# 2532  Valorant Champions 2024  All Stages  All Match Types  Sunset  brimstone
# 2533  Valorant Champions 2024  All Stages  All Match Types  Sunset      astra
# 2534  Valorant Champions 2024  All Stages  All Match Types  Sunset       skye
# 2535  Valorant Champions 2024  All Stages  All Match Types  Sunset       yoru
# 2536  Valorant Champions 2024  All Stages  All Match Types  Sunset     harbor
# 2537  Valorant Champions 2024  All Stages  All Match Types  Sunset   deadlock
# 2538  Valorant Champions 2024  All Stages  All Match Types  Sunset       sage
# 2539  Valorant Champions 2024  All Stages  All Match Types  Sunset      clove
# 2540  Valorant Champions 2024  All Stages  All Match Types  Sunset    chamber
# 2541  Valorant Champions 2024  All Stages  All Match Types  Sunset        iso
# 2542  Valorant Champions 2024  All Stages  All Match Types  Sunset    phoenix
# 2543  Valorant Champions 2024  All Stages  All Match Types  Sunset      reyna
#
#       Pick Rate
# 2520       0.93
# 2521       0.75
# 2522       0.00
# 2523       0.93
# 2524       0.46
# 2525       0.11
# 2526       0.00
# 2527       0.00
# 2528       0.14
# 2529       0.57
# 2530       0.54
# 2531       0.39
# 2532       0.00
# 2533       0.07
# 2534       0.00
# 2535       0.00
# 2536       0.00
# 2537       0.04
# 2538       0.07
# 2539       0.00
# 2540       0.00
# 2541       0.00
# 2542       0.00
# 2543       0.00

# %%
Agentspick = Data_AllMaps[['Agent','Pick Rate']]
Agentspick

# Membuat DataFrame
AgentspickLotus = pd.DataFrame(Agentspick)

# Menghapus baris dengan 'Pick Rate' yang bernilai 0
AgentspickLotus_cleaned = AgentspickLotus[AgentspickLotus['Pick Rate'] != 0]

# %%
AgentspickLotus_cleaned
# Out:
#          Agent  Pick Rate
# 2520      omen       0.93
# 2521      sova       0.75
# 2523    cypher       0.93
# 2524      raze       0.46
# 2525      fade       0.11
# 2528     gekko       0.14
# 2529    breach       0.57
# 2530      neon       0.54
# 2531      kayo       0.39
# 2533     astra       0.07
# 2537  deadlock       0.04
# 2538      sage       0.07

# %%
AgentspickLotus_cleaned['Pick Rate'] = AgentspickLotus_cleaned['Pick Rate'] * 100
AgentspickLotus_cleaned = AgentspickLotus_cleaned.sort_values(by='Pick Rate', ascending=False)
plt.bar(AgentspickLotus_cleaned['Agent'], AgentspickLotus_cleaned['Pick Rate'], color='skyblue')
plt.title('Pick Rate of Agents Chammpions Korea (Map Sunset)')
plt.xlabel('Agent ')
plt.ylabel('Pick Rate (%)')
plt.xticks(rotation=45, ha='right')

# Menampilkan plot
plt.tight_layout()  # Agar layout lebih rapih
plt.show()
# Out:
# C:\Users\Ubaidil\AppData\Local\Temp\ipykernel_13208\563889081.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   AgentspickLotus_cleaned['Pick Rate'] = AgentspickLotus_cleaned['Pick Rate'] * 100

# %%
file_path = 'AgentsPickChampionsKoreaSunset.xlsx' 
Agentspick.to_excel(file_path, index=False, engine='openpyxl')

print(f"Data berhasil disimpan ke {file_path}")
# Out:
# Data berhasil disimpan ke AgentsPickChampionsKoreaSunset.xlsx
