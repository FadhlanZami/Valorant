# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, classification_report 
import seaborn as sns

# %%
data=pd.read_excel(r"C:\Users\Ubaidil\Downloads\vct_2024\agents\agent_pick_rates.xlsx")
Data_champions = data[data['Tournament'].isin(['Valorant Champions 2024'])]

# %%
Data_allStages = Data_champions[Data_champions['Stage'].isin(['All Stages'])]
Data_allStages
# Out:
#                    Tournament       Stage       Match Type       Map    Agent  \
# 2448  Valorant Champions 2024  All Stages  All Match Types  All Maps     omen
# 2449  Valorant Champions 2024  All Stages  All Match Types  All Maps     sova
# 2450  Valorant Champions 2024  All Stages  All Match Types  All Maps    viper
# 2451  Valorant Champions 2024  All Stages  All Match Types  All Maps   cypher
# 2452  Valorant Champions 2024  All Stages  All Match Types  All Maps     raze
# ...                       ...         ...              ...       ...      ...
# 2635  Valorant Champions 2024  All Stages  All Match Types    Ascent    clove
# 2636  Valorant Champions 2024  All Stages  All Match Types    Ascent  chamber
# 2637  Valorant Champions 2024  All Stages  All Match Types    Ascent      iso
# 2638  Valorant Champions 2024  All Stages  All Match Types    Ascent  phoenix
# 2639  Valorant Champions 2024  All Stages  All Match Types    Ascent    reyna
#
#       Pick Rate
# 2448       0.62
# 2449       0.52
# 2450       0.50
# 2451       0.42
# 2452       0.41
# ...         ...
# 2635       0.13
# 2636       0.00
# 2637       0.00
# 2638       0.13
# 2639       0.00
#
# [192 rows x 6 columns]

# %%
Data_AllMaps = Data_allStages[Data_allStages['Map'].isin(['Haven'])]
Data_AllMaps
# Out:
#                    Tournament       Stage       Match Type    Map      Agent  \
# 2592  Valorant Champions 2024  All Stages  All Match Types  Haven       omen
# 2593  Valorant Champions 2024  All Stages  All Match Types  Haven       sova
# 2594  Valorant Champions 2024  All Stages  All Match Types  Haven      viper
# 2595  Valorant Champions 2024  All Stages  All Match Types  Haven     cypher
# 2596  Valorant Champions 2024  All Stages  All Match Types  Haven       raze
# 2597  Valorant Champions 2024  All Stages  All Match Types  Haven       fade
# 2598  Valorant Champions 2024  All Stages  All Match Types  Haven    killjoy
# 2599  Valorant Champions 2024  All Stages  All Match Types  Haven       jett
# 2600  Valorant Champions 2024  All Stages  All Match Types  Haven      gekko
# 2601  Valorant Champions 2024  All Stages  All Match Types  Haven     breach
# 2602  Valorant Champions 2024  All Stages  All Match Types  Haven       neon
# 2603  Valorant Champions 2024  All Stages  All Match Types  Haven       kayo
# 2604  Valorant Champions 2024  All Stages  All Match Types  Haven  brimstone
# 2605  Valorant Champions 2024  All Stages  All Match Types  Haven      astra
# 2606  Valorant Champions 2024  All Stages  All Match Types  Haven       skye
# 2607  Valorant Champions 2024  All Stages  All Match Types  Haven       yoru
# 2608  Valorant Champions 2024  All Stages  All Match Types  Haven     harbor
# 2609  Valorant Champions 2024  All Stages  All Match Types  Haven   deadlock
# 2610  Valorant Champions 2024  All Stages  All Match Types  Haven       sage
# 2611  Valorant Champions 2024  All Stages  All Match Types  Haven      clove
# 2612  Valorant Champions 2024  All Stages  All Match Types  Haven    chamber
# 2613  Valorant Champions 2024  All Stages  All Match Types  Haven        iso
# 2614  Valorant Champions 2024  All Stages  All Match Types  Haven    phoenix
# 2615  Valorant Champions 2024  All Stages  All Match Types  Haven      reyna
#
#       Pick Rate
# 2592       1.00
# 2593       0.89
# 2594       0.17
# 2595       0.78
# 2596       0.06
# 2597       0.00
# 2598       0.22
# 2599       0.22
# 2600       0.06
# 2601       0.67
# 2602       0.50
# 2603       0.00
# 2604       0.00
# 2605       0.00
# 2606       0.06
# 2607       0.22
# 2608       0.00
# 2609       0.00
# 2610       0.06
# 2611       0.00
# 2612       0.00
# 2613       0.11
# 2614       0.00
# 2615       0.00

# %%
Agentspick = Data_AllMaps[['Agent','Pick Rate']]
Agentspick

# Membuat DataFrame
AgentspickLotus = pd.DataFrame(Agentspick)

# Menghapus baris dengan 'Pick Rate' yang bernilai 0
AgentspickLotus_cleaned = AgentspickLotus[AgentspickLotus['Pick Rate'] != 0]

# %%
AgentspickLotus_cleaned
# Out:
#         Agent  Pick Rate
# 2592     omen       1.00
# 2593     sova       0.89
# 2594    viper       0.17
# 2595   cypher       0.78
# 2596     raze       0.06
# 2598  killjoy       0.22
# 2599     jett       0.22
# 2600    gekko       0.06
# 2601   breach       0.67
# 2602     neon       0.50
# 2606     skye       0.06
# 2607     yoru       0.22
# 2610     sage       0.06
# 2613      iso       0.11

# %%
AgentspickLotus_cleaned['Pick Rate'] = AgentspickLotus_cleaned['Pick Rate'] * 100
AgentspickLotus_cleaned = AgentspickLotus_cleaned.sort_values(by='Pick Rate', ascending=False)
plt.bar(AgentspickLotus_cleaned['Agent'], AgentspickLotus_cleaned['Pick Rate'], color='skyblue')
plt.title('Pick Rate of Agents Champions Korea (Map Haven)')
plt.xlabel('Agent ')
plt.ylabel('Pick Rate (%)')
plt.xticks(rotation=45, ha='right')

# Menampilkan plot
plt.tight_layout()  # Agar layout lebih rapih
plt.show()
# Out:
# C:\Users\Ubaidil\AppData\Local\Temp\ipykernel_14512\440029681.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   AgentspickLotus_cleaned['Pick Rate'] = AgentspickLotus_cleaned['Pick Rate'] * 100

# %%
file_path = 'AgentsPickChampionsKoreaHaven.xlsx'                              
Agentspick.to_excel(file_path, index=False, engine='openpyxl')

print(f"Data berhasil disimpan ke {file_path}")
# Out:
# Data berhasil disimpan ke AgentsPickChampionsKoreaHaven.xlsx
